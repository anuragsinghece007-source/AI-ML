# %% [markdown]
# **Earners AI and ML - by Aditya Jain Sir - Lecture 07**

# %% [markdown]
# **Recap = for loop: Quiz**

# %%
# Q1. How many times will the following loop execute?
for i in range(5):
  print("Hello")

# %%
# Q1. How many times will the following loop execute?
# for i in range(5):
#   print("Hello")
# A. 4
# B. 5
# C. 6
# D. Infinite
# Ans: B

# %%
# Q2. what will bw the output?
for i in range(4):
  print(i)

# %%
# Q2. What will be the output?
# for i in range(4):
#   print(i)
# A.
# 1
# 2
# 3
# 4

# B.
# 0
# 1
# 2
# 3

# C.
# 0
# 1
# 2
# 3
# 4
# answer B will be the anser

# %%
# Q3. What numbers are generated by range(3, 8)?
# A.
# 3 4 5 6 7
# B.
# 3 4 5 6 7 8
# anser a from 3 to 7

# %%
# What will be printed?
# for i in range(2, 11, 2):
#   print(i)
# A.
# 2
# 4
# 6
# 8
# 10

# B.
# 2
# 4
# 6
# 8
# 10
# 12

# C.
# 1
# 3
# 5
# 7
# 9


# D. Error

# Ans: A

# %%
#What will be printed?
for i in range(2, 11, 2):
  print(i)

# %%
# What is the output?
# for i in range(10, 0, -2):
#   print(i)
# A.
# 10
# 8
# 6
# 4
# 2
# ***************************************************************************************************************
# B.
# 10
# 8
# 6
# 4
# 2
# 0
# ***************************************************************************************************************
# C.
# 10
# 8
# 6
# 4
# 2
# ***************************************************************************************************************
# D.
# 10
# 8
# 6
# 4
# 2
# 1
# ***************************************************************************************************************

# # D. Error


# # Ans: A

# %%
for i in range(10 , 0 , -2):
  print(i)

# %%
#  does range(5) generate?
# A.
# 1 2 3 4 5
# B.
# 0 1 2 3 4
# C.
# 0 1 2 3 4 5
# D.
# 5
# Ans: B

# %%
# Q7. Which keyword is used to create a for loop?
# A. repeat
# B. while
# C. for
# D. loop
# Ans: C

# %%
for i in range(1, 6):
    print(i * i)

# %%
# Q9. What will this print?
# for ch in "Python":
#     print(ch)

# A.
# Python

# B.
# Error

# C.
# P y t h o n

# D.
# P
# y
# t
# h
# o
# n

# %%
for ch in "python":
  print(ch)

# %%
for ch in "python":
  print(ch , end = "   ")

# %%
# Which of the following is the correct syntax?
# A.
# for i range(5):
# **************************************************************************************
# B.
# for(i in range(5)):
# **************************************************************************************
# C.
# for i in range(5):
# **************************************************************************************
# D.
# for range(5):
# **************************************************************************************
# Ans: C

# %%
# What will be the output?
# for i in range(5, 1, -1):
#     print(i)
# **************************************************************************************
# A.
# 5
# 4
# 3
# 2
# **************************************************************************************
# B.
# 5
# 4
# 3
# 2
# 1
# **************************************************************************************
# C.
# 1
# 2
# 3
# 4
# 5
# **************************************************************************************
# D. Error
# **************************************************************************************
# Ans .A

# %%
# for i in range(1, 10, 3):
#     print(i)
# **************************************************************************************
# A.
# 1
# 4
# 7
# **************************************************************************************
# B.
# 1
# 3
# 6
# 9
# **************************************************************************************
# C.
# 1
# 4
# 7
# 10
# **************************************************************************************
# D. 7, 10
# **************************************************************************************
# ANS A:

# %%
# How many times will the following loop execute?
# for i in range(1, 11, 2):
#     print(i)
# A. 4
# B. 5
# C. 6
# D. 10
# Ans : B

# %%
# How many times will the following loop execute?
# for i in range(1, 11, 2):
#     print(i)
# A. 4
# B. 5
# C. 6
# D. 10
# Ans : B

# %%
# What is the output?
# for i in range(3, 3):
# print(i)
# A.
# 3
# B.
# 0
# C. Nothing
# D. Error
# Ans : C

# %%
for i in range(3, 3):
  print(i)

# %%
# Which statement about range(start, stop) is TRUE?
# A. Both start and stop are included.
# B. Only stop is included.
# C. start is included, stop is excluded.
# D. Both are excluded.
# Ans: C

# %%
# What is the output?
# for i in range(4):
# print(i + 10)
# A.
# 10
# 11
# 12
# 13

# B.
# 11
# 12
# 13
# 14

# C.
# 10
# 20
# 30
# 40
# D. Error

# answer a.

# %%
# Predict the output.
# for i in range(2):
#   print("Python")
#   print("AI")
# 88888888888888888888888888888888888888
# A.
# Python
# AI
# 88888888888888888888888888888888888888
# B.**********
# Python
# AI
# Python
# AI
# 88888888888888888888888888888888888888
# C.
# Python
# Python
# AI
# AI
# 88888888888888888888888888888888888888
# D. Infinite Loo

# %%
for i in range(10):
  print("Python")
  print("AI")

# %%
for i in range(10):
  print("Python",i)

# %%
for i in range(2):
    print("Python")
print("AI")

# %%
name = "Data"
for ch in name:
        if ch == "a":
          print(ch)
# A.
# a
# B.
# a
# a
# C.
# Data
# D. Error

# %%
# write a program to print hi 7 times on the screen \
i=1
while i<=7:
  print(i,"hi")
  i=i+1

# %%
i = 1
while i<=7:
  print(i , "Hii")
  i+=1

# %%
i = 7
while i >= 1:
  print(i , "Hii")
  i=i-1

# %%
# wap for even numbers between 0 to 10 both inclusive using while loop
i = 0
while i<11:
  print(i)
  i+=2

# %%
i = 0
while i<11:
  if i%2==0:
    print(i)
  i+=1

# %%
# print all the odd number between 0 to 10
i = 1
while(i<11):
  if(i%2!=0):
    print(i)
    i+=1
# Out:
# 1
