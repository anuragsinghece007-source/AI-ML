# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/Earners_Restart_AI%26ML_1_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Earners AI&ML Lecture no. -->1.7

# %% [markdown]
# # Recap = for loop: Quiz

# %%
# Q1. How many times will the following loop execute?
for i in range(5):
  print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
# Q1. How many times will the following loop execute?
# for i in range(5):
#   print("Hello")
# A. 4
# B. 5
# C. 6
# D. Infinite
# Ans: B

# %%
# Q2. what will be the output?
for i in range(4):
  print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
# Q2. What will be the output?
# for i in range(4):
#   print(i)
# A.
# 1
# 2
# 3
# 4

# B.
# 0
# 1
# 2
# 3

# C.
# 0
# 1
# 2
# 3
# 4
# answer B will be the answer

# %%
# Q3. What numbers are generated by range(3, 8)?
# A.
# 3 4 5 6 7
# B.
# 3 4 5 6 7 8
# anser a from 3 to 7

# %%
# What will be printed?
# for i in range(2, 11, 2):
#   print(i)
# A.
# 2
# 4
# 6
# 8
# 10

# B.
# 2
# 4
# 6
# 8
# 10
# 12

# C.
# 1
# 3
# 5
# 7
# 9


# D. Error

# Ans: A

# %%
#What will be printed?
for i in range(2, 11, 2):
  print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# What is the output?
# for i in range(10, 0, -2):
#   print(i)
# A.
# 10
# 8
# 6
# 4
# 2
# ***************************************************************************************************************
# B.
# 10
# 8
# 6
# 4
# 2
# 0
# ***************************************************************************************************************
# C.
# 10
# 8
# 6
# 4
# 2
# ***************************************************************************************************************
# D.
# 10
# 8
# 6
# 4
# 2
# 1
# ***************************************************************************************************************

# # D. Error


# # Ans: A

# %%
for i in range(10 , 0 , -2):
  print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
#  does range(5) generate?
# A.
# 1 2 3 4 5
# B.
# 0 1 2 3 4
# C.
# 0 1 2 3 4 5
# D.
# 5
# Ans: B

# %%
# Q7. Which keyword is used to create a for loop?
# A. repeat
# B. while
# C. for
# D. loop
# Ans: C

# %%
for i in range(1, 6):
    print(i * i)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
# Q9. What will this print?
# for ch in "Python":
#     print(ch)

# A.
# Python

# B.
# Error

# C.
# P y t h o n

# D.
# P
# y
# t
# h
# o
# n

# %%
for ch in "python":
  print(ch)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for ch in "python":
  print(ch , end = "   ")
# Out:
# p   y   t   h   o   n

# %%
# Which of the following is the correct syntax?
# A.
# for i range(5):
# **************************************************************************************
# B.
# for(i in range(5)):
# **************************************************************************************
# C.
# for i in range(5):
# **************************************************************************************
# D.
# for range(5):
# **************************************************************************************
# Ans: C

# %%
# What will be the output?
# for i in range(5, 1, -1):
#     print(i)
# **************************************************************************************
# A.
# 5
# 4
# 3
# 2
# **************************************************************************************
# B.
# 5
# 4
# 3
# 2
# 1
# **************************************************************************************
# C.
# 1
# 2
# 3
# 4
# 5
# **************************************************************************************
# D. Error
# **************************************************************************************
# Ans .A

# %%
# for i in range(1, 10, 3):
#     print(i)
# **************************************************************************************
# A.
# 1
# 4
# 7
# **************************************************************************************
# B.
# 1
# 3
# 6
# 9
# **************************************************************************************
# C.
# 1
# 4
# 7
# 10
# **************************************************************************************
# D. 7, 10
# **************************************************************************************
# ANS A:

# %%
# How many times will the following loop execute?
for i in range(1, 11, 2):
    print(i)
# A. 4
# B. 5
# C. 6
# D. 10
# Ans : B
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# How many times will the following loop execute?
# for i in range(1, 11, 2):
#     print(i)
# A. 4
# B. 5
# C. 6
# D. 10
# Ans : B

# %%
for i in range(3, 3):
  print(i)

# %%
# Which statement about range(start, stop) is TRUE?
# A. Both start and stop are included.
# B. Only stop is included.
# C. start is included, stop is excluded.
# D. Both are excluded.
# Ans: C

# %%
# What is the output?
# for i in range(4):
# print(i + 10)
# A.
# 10
# 11
# 12
# 13

# B.
# 11
# 12
# 13
# 14

# C.
# 10
# 20
# 30
# 40
# D. Error

# answer a.

# %%
#Predict the output.
for i in range(2):
  print("Python")
  print("AI")
# Out:
# Python
# AI
# Python
# AI

# %%
for i in range(10):
  print("Python",i)
# Out:
# Python 0
# Python 1
# Python 2
# Python 3
# Python 4
# Python 5
# Python 6
# Python 7
# Python 8
# Python 9

# %%
for i in range(2):
    print("Python")
print("AI")
# Out:
# Python
# Python
# AI

# %%
name = "Data"
for ch in name:
        if ch == "a":
          print(ch)
# A.
# a
# B.
# a
# a
# C.
# Data
# D. Error
# Out:
# a
# a

# %% [markdown]
# # While Loop

# %% [markdown]
# # while loop 1. initialization , 2. condition , 3. updation

# %%
# write a program to print hi 7 times on the screen \
i=1
while i<=7:
  print(i,"hi")
  i=i+1
# Out:
# 1 hi
# 2 hi
# 3 hi
# 4 hi
# 5 hi
# 6 hi
# 7 hi

# %%
i = 1
while i<=7:
  print(i , "Hii")
  i+=1
# Out:
# 1 Hii
# 2 Hii
# 3 Hii
# 4 Hii
# 5 Hii
# 6 Hii
# 7 Hii

# %%
i = 7
while i >= 1:
  print(i , "Hii")
  i=i-1
# Out:
# 7 Hii
# 6 Hii
# 5 Hii
# 4 Hii
# 3 Hii
# 2 Hii
# 1 Hii

# %%
# wap for even numbers between 0 to 10 both inclusive using while loop
i = 0
while i<11:
  print(i)
  i+=2
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
i = 0
while i<11:
  if i%2==0:
    print(i)
  i+=1
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
i = 1 # here people make mistake
while i<11:
  if i%2!=0:
    print(i)
  i+=1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10):
  if i%2==0:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# print all the odd number between 0 to 10
i = 1
while(i<11):
  if(i%2!=0):
    print(i)
  i+=1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# print the sum of all the nuber btw 1 to 10 (both inclusive)
# 1. for loop
# 2. while loop

# %%
sum = 0
for i in range(1,11):
  sum += i
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
sum = 0
i = 1
while i<=10:
  sum += i
  i += 1

print(sum)
# Out:
# 55

# %%
# print all the multiplications table of 5 till its first 10 multiples:
5*1 = 5

# %%
n = 5
i = 1

while i<=10:
  print(n ," *" ,i, "=",n*i)
  i += 1
# Out:
# 5  * 1 = 5
# 5  * 2 = 10
# 5  * 3 = 15
# 5  * 4 = 20
# 5  * 5 = 25
# 5  * 6 = 30
# 5  * 7 = 35
# 5  * 8 = 40
# 5  * 9 = 45
# 5  * 10 = 50

# %%
count = 1
while count<=3:
  print(count)
  count += 1
# Out:
# 1
# 2
# 3

# %%
# How many times will the following loop execute?
count = 5
while count <= 10:
  print(count)
  count += 1
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
# How many times will the following loop execute?
count = 5
while count <= 10:
  print(count)
  count += 1
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
count = 10
while count >= 8:
  print(count)
  count -= 1
# Out:
# 10
# 9
# 8

# %%
# Which statement is TRUE about a while loop?
# A. It always runs exactly 10 times.
# B. It runs as long as its condition is True.
# C. It can only print numbers.
# # D. It always requires range()

# %%
count = 1
while count < 1:
  print("Hello")

# %%
# Which of the following is the correct syntax?
# A.
# while i < 5
# B.
# while(i < 5)
# C.
# while i < 5:
# D.
# while i = 5:

# %%
num = 2
while num <= 8:
  print(num)
  num += 2
# Out:
# 2
# 4
# 6
# 8

# %%
count = 5
while count > 0:
  print(count)
  count -= 2
# Out:
# 5
# 3
# 1

# %% [markdown]
# # HOMEWORK

# %%
count = 1
while count <= 5:
  count += 1
  print(count)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
count = 1
while count <= 5:
  count += 1
print(count)
# Out:
# 6

# %%
# Which situation is best suited for a while loop?
# A. Print numbers from 1 to 10.
# B. Print multiplication table of 5.
# C. Keep asking for a password until the correct one is entered.
# D. Print the first 20 even numbers.

# %%
x = 0
while x < 3:
  print(x)
  x += 1



print("Done")
# Out:
# 0
# 1
# 2
# Done
