# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/Earners_Restart_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI & ML by Aditya Jain sir --> Lecture 2

# %% [markdown]
# # HW

# %%
 #1. What will be printed?
print(10)
# A. Ten
# B. "10"
# C. 10
# D. Error
# Out:
# 10

# %%
print(10)
# Out:
# 10

# %%
# Guess the output:
print(5 + 3)
# Output?
# A. 53
# B. 8
# C. 5+3
# D. Error
# Out:
# 8

# %%
print(5+3)
# Out:
# 8

# %%
print("5+3")
# Out:
# 5+3

# %%
print("Anurag singh")
print("Vidhi")
# Out:
# Anurag singh
# Vidhi

# %%
 # Q- What's the output?
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3055/2432636147.py in <cell line: 0>()
#       1 # Q- What's the output?
# ----> 2 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A", "B" , "C")
# Out:
# A B C

# %% [markdown]
# # Comments

# %%
# This code is to print anurag singh
print("Anurag singh")
# Out:
# Anurag singh

# %%
#  This code
# prints AJ on the screen
print("Anurag singh")
# Out:
# Anurag singh

# %%
# print("Hello")
print("Python")
# A.
# Hello
# Python
# B.
# Hello
# C.
# Python
# D. Error
# Out:
# Python

# %% [markdown]
# # Variables

# %%
name = "AJ"
city = "Nagpur"
id = 24

# %%
print(name)
# Out:
# AJ

# %%
print(id)
# Out:
# 24

# %%
print(City) # yha error ayaa hai becoz city ka c caps m hai y=toh python case sensitive langugae hai toh error ayeaga
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3055/110896076.py in <cell line: 0>()
# ----> 1 print(City) # yha error ayaa hai becoz city ka c caps m hai y=toh python case sensitive langugae hai toh error ayeaga
#
# NameError: name 'City' is not defined

# %%
print(city)
# Out:
# Nagpur

# %%
#Variable naming rules
# 1. Start: Alphabet , _
# 2. Middle or end --> Alphabet, _, digits

# %%
# student_name --> yes
# _marks --> yes
# City --> yes
# State5 --> yes
# 4city --> no
# student-name --> no

# %%
# variable_name = value

# %%
name = "AJ"
city = "Nagpur"
state = "Maharashtra"
id = 24

# %%
# first name = "Aditya"
firstName = "Aditya"
first_name = "Aditya"

# %%
college = "RCOEM"
college = "IIT Bombay"
print(college)
# Out:
# IIT Bombay

# %%
college = "RCOEM"
print(college)
college = "IIT Bombay"
print(college)
# Out:
# RCOEM
# IIT Bombay

# %% [markdown]
# # Data Types

# %%
# 1. Integer --> int
# eg: 50, 4, -6, 0, 22
# 2. Float --> decimal (also called double)
# eg: 5.7, -4.5, 3.6, 2.0
# 3. String (text data) --> str
# "Aditya", "Nagpur" , "Aditya Jain"
# 4. Boolean --> True/False --> bool

# %%
# "4" --> str
# 5 --> int
# True --> bool
# length = 6.7 --> float

# %%
type("4")
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(6.7)
# Out:
# float

# %%
type("5.7")
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type("false")
# Out:
# str

# %% [markdown]
# # Taking input from the user

# %%
name = "Vidhi "

# %%
# input()

# %%
name = input()
# Out:
# Anurag singh

# %%
print(name)
# Out:
# Anurag singh

# %%
# Q. Take two int as input from the user and print there sum
a = int(input())
b = int(input())
sum = a+b
print(sum)
# Out:
# 3
# 5
# 8

# %%
a=input()
# Out:
# 4

# %%
b = input()
# Out:
# 8

# %%
print(a+b)
# Out:
# 48

# %% [markdown]
# # #string concatenation

# %%
age = "20"
new_age = int(age) #typecasting
type(new_age)
# Out:
# int

# %%
type(age)
# Out:
# str

# %%
a = input()
b = input()
c = int(a) + int(b)
print(c)
# Out:
# 2
# 3
# 5

# %%
#mentos zindagi
a = int(input())
b = int(input())
c = a+b
print(c)
# Out:
# 3
# 7
# 10

# %%
birth_year = int(input())
age = 2026-birth_year
print(age)
# Out:
# 2003
# 23

# %%
# Q. Take length and breadth of the rectangle as input and print its area.
# area = l*b

# %%
l = input()
b = input()
area = int(l)*int(b)
print(area)
# Out:
# 7
# 8
# 56

# %%
# Q. Take length and breadth of the rectangle as input and print its area.
# area = l*b

l = input()
b = input()
area = int(l)*int(b)
print(area)
# Out:
# 4.5
# 9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3055/2061512981.py in <cell line: 0>()
#       4 l = input()
#       5 b = input()
# ----> 6 area = int(l)*int(b)
#       7 print(area)
#
# ValueError: invalid literal for int() with base 10: '4.5'

# %%
a = float(input())
b = float(input())
area = a*b
print(area)
# Out:
# 7.0
# 8
# 56.0

# %%
# Q. Take the name, age and height (in inches) of the student as input and print them.

# %%
name = input()
age = int(input())
height = float(input())
print("--------------------------")
print(name, age, height)
# Out:
# Anurag singh
# 90
# 7.5
# --------------------------
# Anurag singh 90 7.5

# %% [markdown]
# # Quizes

# %%
# # 2
# Which is a valid variable?
# A- student_name
# B- 1student
# C- student-name
# D- student name
# Ans: A

# %%
# Q3
# Data type of:
# type(100) --> int
# type("4.5") --> str

# %%
# Q4.
num1 = input()
num2 = input()
print(num1 + num2)
# Input:
# 10
# 20
# Ans: 1020
# Out:
# 10
# 20
# 1020

# %%
is_student = True
type(is_student)
# Out:
# bool

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
print(type("Python"))
# Out:
# <class 'str'>

# %% [markdown]
# # HW

# %%
name = input("Enter your name:")
# A. Prints the name
# B. Takes input from the user
# C. Deletes the name
# D. Creates an error
# Out:
# Enter your name:anurag singh

# %%
type(input())
# Out:
# anurag singh
# str
