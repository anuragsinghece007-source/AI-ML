# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/EARNERS_AI%26ML_(LIST%2CSTRING)Restart_1_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # # EARNERS AI & ML by Aditya Jain sir - Lecture 11

# %% [markdown]
# # # RECAP - LIST

# %%
a = [4,6,7,2,1]

# %%
print(a)
# Out:
# [4, 6, 7, 2, 1]

# %%
type(a)
# Out:
# list

# %%
n = len(a)

# %%
n
# Out:
# 5

# %%
for i in range(n):
  print(i, a[i])
# Out:
# 0 4
# 1 6
# 2 7
# 3 2
# 4 1

# %%
for ele in a:
  print(ele)
# Out:
# 4
# 6
# 7
# 2
# 1

# %%
# print the element of a list in a reverse manner:
for i in range(n):
  print(i,a[n-1-i])
# Out:
# 0 1
# 1 2
# 2 7
# 3 6
# 4 4

# %%
for i in range(2):
  for j in range(2):
    print(j , end =" ")
  print()
# Out:
# 0 1
# 0 1

# %%
numbers = [1, 2, 3, 4] # Initial State   numbers = [1, 2, 3, 4]

n = len(numbers)
for i in range(n):
  numbers[i] = numbers[i] + i

print(numbers)
# Out:
# [1, 3, 5, 7]

# %%
marks = [65, 75, 85]
total = 0
for m in marks:
  if m >= 70:
    total += m
  print(total)
# Out:
# 0
# 75
# 160

# %%
marks = [65, 75, 85]
total = 0
for m in marks:
  if m >= 70:
    total += m
print(total)
# Out:
# 160

# %%
nums = [2, 4, 6]
nums[0] = nums[2]
nums[2] = nums[1]
print(nums)
# Out:
# [6, 4, 4]

# %%
name  = ["I " , " Loves" , "vidhi singh"]
longest = name[0]
for n in name:
  if len(n) > len(longest):
    longest = n
print(name)
# Out:
# ['I ', ' Loves', 'vidhi singh']

# %%
names = ["Amit", "Neha", "vidhi singh"]
longest = names[0]
for name in names:
  if len(name) > len(longest):
    longest = name
print(longest)
# Out:
# vidhi singh

# %%
name = ["anurag", "vidhisingh" , "love"]
longest = name[0]
for names in name:
  if len(names) > len(longest):
    longest = names
print(longest)
# Out:
# vidhisingh

# %%
data = [10 ,20 ,30]
for i in range(len(data)):
  data[i] = data[i]+10

print(data)
# Out:
# [20, 30, 40]

# %%
data = [10, 20, 30]
for i in range(len(data)):
  data[i] = data[i] + 10
print(max(data))
print(min(data))
# Out:
# 40
# 20

# %%
numbers = [5, 10, 15, 20]
total = 0
for i in range(len(numbers)):
    if i % 2 == 0:
      total += numbers[i]
print(total)
# Out:
# 20

# %% [markdown]
# # # LIST SLICING

# %%
a = [5, 7, 4, 8, 2, 1, 9]
print(a)
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
print(a[1:4]) # here index one se start hoga and n-1 index tk jayega
# Out:
# [7, 4, 8]

# %%
print(a[2:5])# here index two se start hoga and n-1 index tk jayega
# Out:
# [4, 8, 2]

# %%
print(a[2:5])# here index two se start hoga and n-1 index tk jayega
# Out:
# [4, 8, 2]

# %%
print(a[:4])
# Out:
# [5, 7, 4, 8]

# %%
print(a[1:])# here 1 se start hoga nad last tk jayega
# Out:
# [7, 4, 8, 2, 1, 9]

# %%
print(a[ : ])
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %%
print(a[ :  :2])
# Out:
# [5, 4, 2, 9]

# %%
print(a)
# Out:
# [5, 7, 4, 8, 2, 1, 9]

# %% [markdown]
# # # STRING

# %%
name = "Aj"

# %%
name = "Aj"

# %% [markdown]
# # QUIZ

# %%
name = "Aj"

# %%
word = "Python"
print(word[3])
# Out:
# h

# %%
text = "Machine"
print(text[-2])
# Out:
# n

# %%
text = "Machine"
print(text[-2])
# Out:
# n

# %%
first = "Data"
second = "Science"
print(first + second)
# Out:
# DataScience

# %%
print("AI. " * 3)
# Out:
# AI. AI. AI.

# %%
print("Aditya")
print("-"*20)
print("Jain")
# Out:
# Aditya
# --------------------
# Jain

# %%
word = "Python"
print("z" not in word)
# Out:
# True

# %%
word = "Python"
print("z" not in word)
# Out:
# True

# %%
word = "Code"
for i in range(len(word)):
  print(i, word[i])
# Out:
# 0 C
# 1 o
# 2 d
# 3 e

# %%
text = "Python"
i = 0
while i < len(text):
  print(text[i])
  i += 2
# Out:
# P
# t
# o
