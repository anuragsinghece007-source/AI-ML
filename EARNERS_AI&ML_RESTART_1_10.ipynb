# %% [markdown]
# # EARNERS AI & ML by Aditya Jain sir - lecture 10

# %% [markdown]
# # Recap

# %%
for i in range(5):
  for j in range(6,10):
    print(i,j)
# Out:
# 0 6
# 0 7
# 0 8
# 0 9
# 1 6
# 1 7
# 1 8
# 1 9
# 2 6
# 2 7
# 2 8
# 2 9
# 3 6
# 3 7
# 3 8
# 3 9
# 4 6
# 4 7
# 4 8
# 4 9

# %% [markdown]
# # HW of Last Lecture

# %%
for i in range(2):
  for j in range(2):
    print(j, end=" ")
  print()
# Out:
# 0 1
# 0 1

# %%
for row in range(4):
  for col in range(4):
    print("#", end=" ")
  print()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
for i in range(1,3):
  for j in range(1,3):
    print(i + j, end=" ")
  print()
# Out:
# 2 3
# 3 4

# %% [markdown]
# # List

# %%
m1 = 90
m2 = 86
m3 = 95
m4 = 83
m5 = 70

# %%
marks = [90, 86, 95, 83, 70]

# %%
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
a = [45, "AJ", 6.8, True]

# %%
print(a)
# Out:
# [45, 'AJ', 6.8, True]

# %%
type(a)
# Out:
# list

# %%
type(marks)
# Out:
# list

# %%
students = []
print(students)
# Out:
# []

# %% [markdown]
# # Indexing

# %%
#indexing starts at 0
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[0]
# Out:
# 90

# %%
marks[2]
# Out:
# 95

# %%
marks[4]
# Out:
# 70

# %%
n = len(marks)

# %%
n
# Out:
# 5

# %%
marks[n-1]
# Out:
# 70

# %%
marks[n-2]
# Out:
# 83

# %%
marks[-1]
# Out:
# 70

# %%
marks[-2]
# Out:
# 83

# %%
marks
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[2]=100

# %%
marks
# Out:
# [90, 86, 100, 83, 70]

# %%
# marks(2) = 97

# %% [markdown]
# # Iterating over a list

# %%
n = len(marks)
n
# Out:
# 5

# %%
marks[0]
# Out:
# 90

# %%
marks[1]
# Out:
# 86

# %%
for i in range(n):
  print(marks[i])
# Out:
# 90
# 86
# 100
# 83
# 70

# %%
for ele in marks:
  print(ele)
# Out:
# 90
# 86
# 100
# 83
# 70

# %%
marks
# Out:
# [90, 86, 100, 83, 70]

# %%
#Write a code to print the elements present at even indexes
for i in range(n):
  if i%2 == 0:
    print(marks[i])
# Out:
# 90
# 100
# 70

# %%
#Write a code to print all the even elements
for i in range(n):
  if marks[i]%2 == 0:
    print(marks[i])
# Out:
# 90
# 86
# 100
# 70

# %%
for elem in marks:
  if elem%2 == 0:
    print(elem)
# Out:
# 90
# 86
# 100
# 70

# %% [markdown]
# # Quiz

# %%
What is the output?
numbers = [10, 20, 30]
print(numbers[0])
# Out:
# Object `output` not found.
# 10

# %%
numbers = [10, 20, 30]
print(numbers[0])
# Out:
# 10

# %%
# What is the output?
fruits = ["Apple", "Banana", "Mango"]
print(fruits[-1])
# Out:
# Mango

# %%
# What is the output?
marks = [70, 80, 90]
print(len(marks))
# Out:
# 3

# %%
# Which of the following is a valid Python list?
# A.
# marks = (10,20,30)
# B.
# marks = {10,20,30}
# C.
# marks = [10,20,30]
# D.
# marks = <10,20,30>
# ans : C

# %%
# What is the output?
numbers = [5,10,15,20]
print(numbers[-2])
# Out:
# 15

# %%
# What is the output?
fruits = ["Apple","Banana","Mango"]
fruits[1] = "Orange"
print(fruits)
# Out:
# ['Apple', 'Orange', 'Mango']

# %%
# What is the output?
numbers = [10,20]
print(numbers[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1191/3400737244.py in <cell line: 0>()
#       1 # What is the output?
#       2 numbers = [10,20]
# ----> 3 print(numbers[2])
#
# IndexError: list index out of range

# %%
# What is the output?
numbers = [1,2,3]
for num in numbers:
  print(num)
# Out:
# 1
# 2
# 3

# %%
# What is printed?
numbers = [5,10,15]
for i in range(len(numbers)):
  print(numbers[i])
# Out:
# 5
# 10
# 15

# %%
# What is the output?
marks = [60,70,80,90]
print(max(marks))
# Out:
# 90

# %%
marks = [60,70,80,90]
print(min(marks))
# Out:
# 60

# %%
#Write a code to find the sum of all the elements of the list.
marks = [60,70,80,90]
sm = 0
for elem in marks:
  sm = sm + elem
print(sm)
# Out:
# 300

# %%
# Write a code to find the average of all the elements of the list.

# %%
marks = [60,70,80,90]
n = len(marks)
sm = 0
for elem in marks:
  sm = sm + elem
  print(sm/n)
# Out:
# 15.0
# 32.5
# 52.5
# 75.0

# %%
# What is printed?
numbers = [9,5,7,1]
print(sorted(numbers))
# Out:
# [1, 5, 7, 9]

# %%
numbers
# Out:
# [9, 5, 7, 1]

# %%
numbers.sort()

# %%
print(numbers)
# Out:
# [1, 5, 7, 9]

# %%
# What is the output?
names = ["A","B","C"]
print(names[len(names)-1])
# Out:
# C

# %%
numbers = [5, 10, 15]
numbers[1] = numbers[0] + numbers[2]
print(numbers)
print(sum(numbers))
# Out:
# [5, 20, 15]
# 40

# %%
marks = [50, 60, 70, 80]
for i in range(len(marks)):
  marks[i] = marks[i] + 5
print(marks)
# Out:
# [55, 65, 75, 85]

# %%
data = [2, 4, 6]
for i in range(len(data)):
  print(i, data[i])
# Out:
# 0 2
# 1 4
# 2 6

# %%
items = [1, 2, 3]
for i in range(len(items)):
  items[i] = items[i] * 2
print(sum(items))
# Out:
# 12

# %%
numbers = [10, 20, 30]
print(numbers[-1])
numbers[-1] = 100
print(numbers)
# Out:
# 30
# [10, 20, 100]

# %%
nums = [2, 4, 6, 8]
count = 0
for n in nums:
  if n > 4:
    count += 1
print(count)
# Out:
# 2

# %%
marks = [80, 75, 90]
highest = max(marks)
for m in marks:
  print(highest - m)
# Out:
# 10
# 15
# 0

# %%
numbers = [3, 5, 7]
result = 1
for n in numbers:
#result = result * n
  print(n)
# Out:
# 3
# 5
# 7

# %%
numbers = [3, 5, 7]
result = 1
for n in numbers:
  result = result * n
print(result)
# Out:
# 105
