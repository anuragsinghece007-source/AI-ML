# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/EARNERS_AI%26ML_DICTIONARY_LECTURE_2_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOME WORK

# %%
def check(num):
  if num % 2 == 0:
    return "Even"
  else:
      return "Odd"

# %%
print(check(15))
# Out:
# Odd

# %%
def greet(name):
  print("Hello", name)
greet("Rahul")
# Out:
# Hello Rahul

# %%
def display():
  return("vidhi")

display()
# Out:
# 'vidhi'

# %%
def largest(a, b):
  if a > b:
    return a
  else:
    return b
print(largest(12, 25))
# Out:
# 25

# %%
def total(numbers):
  s = 0 # zero se addkarne se nothing change
  for n in numbers:
    s+=n

  return s

print(total([1, 2, 3, 4, 5]))
# Out:
# 15

# %% [markdown]
# # DICTIONARY

# %%
student = ["anurag" , 22 , 91.5, "sirsa"]

# %%
student
# Out:
# ['anurag', 22, 91.5, 'sirsa']

# %% [markdown]
# # Dictionary stores data in a form of key value pair

# %%
student = { # key : value
"name" : "Rahul",
"age" : 22,
"CGPA" : 91.5,
"city" : "Nagpur"
}

# %%
car =   {
  "vi" : "grandvitara" ,
    "age" : 7,
    "num" : 161,
    "rto" : "rudrapur"

}

# %%
print("vi")
# Out:
# vi

# %%
car
# Out:
# {'vi': 'grandvitara', 'age': 7, 'num': 161, 'rto': 'rudrapur'}

# %%
type(student)
# Out:
# dict

# %%
student["name"]
# Out:
# 'Rahul'

# %%
student["CGPA"]
# Out:
# 91.5

# %%
student["age"]
# Out:
# 22

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
car["vi"]
# Out:
# 'grandvitara'

# %%
car["vi"] = "gwagon"

# %%
car
# Out:
# {'vi': 'gwagon', 'age': 7, 'num': 161, 'rto': 'rudrapur'}

# %%
l = [ 1, 2, 3 ,3 ]
l
# Out:
# [1, 2, 3, 3]

# %%
l[0]
# Out:
# 1

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
student["CGPA"]
# Out:
# 91.5

# %%
print(student)
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur'}

# %%
student["class"] = "8"

# %%
student
# Out:
# {'name': 'Rahul', 'age': 22, 'CGPA': 91.5, 'city': 'Nagpur', 'class': '8'}

# %%
student["age"]
# Out:
# 22

# %%
student["addres"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3061/3729538126.py in <cell line: 0>()
# ----> 1 student["addres"]
#
# KeyError: 'addres'

# %%
student.get("age")
# Out:
# 22

# %%
student["toll"] = "kichha"

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'CGPA': 91.5,
#  'city': 'Nagpur',
#  'class': '8',
#  'toll': 'kichha'}

# %% [markdown]
# # HOW TO GET NO ERROR

# %%
student.get("address")

# %%
student("address")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3061/3323859938.py in <cell line: 0>()
# ----> 1 student("address")
#
# TypeError: 'dict' object is not callable

# %%
student.get('age')
# Out:
# 22

# %%
student.get("address")

# %%
student.get("address", 'age')
# Out:
# 'age'

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'CGPA': 91.5,
#  'city': 'Nagpur',
#  'class': '8',
#  'toll': 'kichha'}

# %%
student.get("address", 'key not found')
# Out:
# 'key not found'

# %%
student.get("age" , "key not found")
# Out:
# 22

# %% [markdown]
# # MINOR DIFFERENCE

# %%
student.get("address")

# %%
student.get("address" , "key not found")
# Out:
# 'key not found'

# %%
student.get("age" , "key not found")
# Out:
# 22

# %% [markdown]
# # HOW TO DELETE KEY AND VALUE FROM DICTIONARY

# %%
student
# Out:
# {'name': 'Rahul',
#  'age': 22,
#  'CGPA': 91.5,
#  'city': 'Nagpur',
#  'class': '8',
#  'toll': 'kichha'}

# %%
student.pop("age")
# Out:
# 22

# %%
student
# Out:
# {'name': 'Rahul',
#  'CGPA': 91.5,
#  'city': 'Nagpur',
#  'class': '8',
#  'toll': 'kichha'}

# %%
student.pop("name")
# Out:
# 'Rahul'

# %%
student
# Out:
# {'CGPA': 91.5, 'city': 'Nagpur', 'class': '8', 'toll': 'kichha'}

# %%
student.pop("CGPA")
# Out:
# 91.5

# %% [markdown]
# # LOOP OVER DICTIONARIES

# %%
student
# Out:
# {'city': 'Nagpur', 'class': '8', 'toll': 'kichha'}

# %%
for k in student.keys():
  print(k)
# Out:
# city
# class
# toll

# %%
for k in student.keys():
  print(student[k])
# Out:
# Nagpur
# 8
# kichha

# %%
for k in student.keys():
  print(student[k])
# Out:
# Nagpur
# 8
# kichha

# %%
for k in student.values():
  print(k)
# Out:
# Nagpur
# 8
# kichha

# %%
for i in student.items():
  print(i)
# Out:
# ('city', 'Nagpur')
# ('class', '8')
# ('toll', 'kichha')

# %%
for elem in student.items():
  print("key =",elem[0], ", value =", elem[1])
# Out:
# key = city , value = Nagpur
# key = class , value = 8
# key = toll , value = kichha

# %% [markdown]
# # QUIZ

# %%
for i in student.items():
  print("keys=" , i[0] , ", value = " ,i[1])
# Out:
# keys= city , value =  Nagpur
# keys= class , value =  8
# keys= toll , value =  kichha

# %%
std = {
    "name " : "anurag singh" ,
    "age" : 22
}

# %%
std
# Out:
# {'name ': 'anurag singh', 'age': 22}

# %%
std = {
    "name " : "anurag singh" ,
    "age" : 22
}
print(std["age"])
# Out:
# 22

# %%
std = {
    "name " : "anurag singh" ,
    "age" : 22
}
print(std["name "])
# Out:
# anurag singh

# %%
# Which of the following correctly creates a dictionary?
# A.
# student = ["name":"Rahul"]
# B.
# student = ("name":"Rahul")
# C.
# student = {"name":"Rahul"}
# D.
# student = <"name":"Rahul">
# Ans: C

# %%
student = {
  "name": "Rahul"
}
student["age"] = 22
print(student)
# Out:
# {'name': 'Rahul', 'age': 22}

# %%
student = {
  "name": "Rahul",
  "age": 22
}
student["age"] = 23
print(student)
# Out:
# {'name': 'Rahul', 'age': 23}

# %%
student = {
  "name":"Rahul",
  "age":22
}
print(len(student))
# Out:
# 2

# %%
student = {
  "name":"Rahul"
}
print(student.get("city"))
# Out:
# None

# %%
student = {
  "name":"Rahul"
}
print(student["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3061/617459473.py in <cell line: 0>()
#       2   "name":"Rahul"
#       3 }
# ----> 4 print(student["city"])
#
# KeyError: 'city'

# %%
student = {
  "name":"Rahul",
  "age":22
}
print(student.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
student = {
  "name":"Rahul",
  "age":22
}
for key in student.keys():
  print(student[key])
# Out:
# Rahul
# 22

# %%
student = {
  "name":"Rahul",
  "age":22
}
for key in student.values():
  print(student.values())
# Out:
# dict_values(['Rahul', 22])
# dict_values(['Rahul', 22])

# %%
student = {
  "name":"Rahul",
  "city":"Nagpur"
}
student.pop("city")
print(student)
# Out:
# {'name': 'Rahul'}

# %%
marks = {
  "Math":90,
  "Science":80,
  "English":95
}
total = 0
for subject in marks.keys():
  total += marks[subject]
print(total)
# Out:
# 265

# %%
cart = {
  "Milk":2,
  "Bread":1
}
cart["Eggs"] = 12
print(len(cart))
# Out:
# 3

# %%
cart
# Out:
# {'Milk': 2, 'Bread': 1, 'Eggs': 12}

# %%
employee = {
"salary":50000
}
employee["salary"] += 10000
print(employee["salary"])
# Out:
# 60000

# %%
student = {
"name":"Rahul",
#"age":22
}
count = 0
for key in student.keys():
  count += 1
print(count)
# Out:
# 1

# %%
student = {
"name": "Rahul",
"age": 22
}
student["city"] = "Nagpur"
student["age"] += 1
print(student["age"])
# Out:
# 23

# %%
marks = {
"Math": 90,
"Science": 80,
"English": 70
}
total = 0
for subject in marks.keys():
  total += marks[subject]
print(total / len(marks))
# Out:
# 80.0

# %%
employee = {
"salary": 50000
}
employee["salary"] = employee["salary"] * 1.10
print(employee["salary"])
# Out:
# 55000.00000000001

# %%
# 10% = 10/100 = 0.1
# x = x + 0.1x = (1 + 0.1)x = 1.1x

# %%
data = {
"A": 10,
"B": 20,
"C": 30
}
count = 0
for key in data.keys():
  if data[key] > 15:
    count += 1
print(count)
# Out:
# 2

# %%
student = {
"name": "Rahul",
"age": 22,
"city": "Nagpur"
}
for key in student.keys():
  print(len(key))
# Out:
# 4
# 3
# 4

# %%
for k in student.keys():
  print(k)
# Out:
# name
# age
# city

# %%
for k in student.keys():
  print(len(k))
# Out:
# 4
# 3
# 4

# %%
student = {
"name": "Rahul",
"age": 22,
"city": "Nagpur"
}
for key in student.keys():
  print(key)
# Out:
# name
# age
# city
