# %% [markdown]
# # # Earners AI and ML by Aditya Jain sir - Lecture 12

# %% [markdown]
# # RECAP STRING

# %%
s = "VIDHI SINGH "

# %%
type(s)
# Out:
# str

# %%
n= len(s)

# %%
n
# Out:
# 12

# %%
s[2]
# Out:
# 'D'

# %%
s[-1]
# Out:
# ' '

# %%
print(s)
# Out:
# VIDHI SINGH

# %%
a = s[1:]

# %%
a
# Out:
# 'IDHI SINGH '

# %%
print(s[:6])
# Out:
# VIDHI

# %%
for i in s:
  print(i, end = "")
# Out:
# VIDHI SINGH

# %%
n = len(s)
for i in range(n):
  print(s[i], end ="")
# Out:
# VIDHI SINGH

# %%
print(s)
# Out:
# VIDHI SINGH

# %%
a = s.split(" ")
print(a)
# Out:
# ['VIDHI', 'SINGH', '']

# %%
s = "anurag singh really love you vidhi singh"
a = s.split("  ")
print(a)
# Out:
# ['anurag singh really love you vidhi singh']

# %%
s = "anurag singh really love you vidhi singh"
a = s.split(" ")
print(a)
# Out:
# ['anurag', 'singh', 'really', 'love', 'you', 'vidhi', 'singh']

# %%
s = "anurag singh likes to do programming"
a = s.split(" ")
print(s)
# Out:
# anurag singh likes to do programming

# %%
for ele in a:
  print(ele)
# Out:
# anurag
# singh
# likes
# to
# do
# programming

# %% [markdown]
# # # HW - DPP- Tricky Advanced Questions

# %%
text = "Programming"
count = 0
for i in range(len(text)):
  if text[i] == text[-1]:
    count += 1
print(count)
# Out:
# 2

# %%
text = "Programming"
len(text)
# Out:
# 11

# %%
word = "PYTHON"
result = ""
for i in range(len(word)):
  if i % 2 == 1:
    result += word[i]

print(result)
# Out:
# YHN

# %%
text = "Data"
result = ""
for ch in text:
  result = ch + result
print(result)
# Out:
# ataD

# %%
text = "Data"
result = ""
for ch in text:
  result = result + ch
print(result)
# Out:
# Data

# %%
word = "Machine"
count = 0
for ch in word:
  if ch not in "aeiAEouIOU":
    count += 1
print(count)
# Out:
# 4

# %%
word = "python"

i = len(word)-1
while i >= 0:
  print(word[i], end="")
  i -= 2
# Out:
# nhy

# %%
word = "python"
len(word)
# Out:
# 6

# %%
text = "AI"
result = ""
for i in range(4):
  result = result + text
print(result)
print(len(result))
# Out:
# AIAIAIAI
# 8

# %%
word = "computer"
count = 0
for ch in word:
  if ch < "m":
    count += 1

print(count)
# Out:
# 2

# %%
ord("A") # ord give character ascii code
# Out:
# 65

# %%
ord("B")
# Out:
# 66

# %%
ord("Z")
# Out:
# 90

# %%
ord("a")
# Out:
# 97

# %%
ord("z")
# Out:
# 122

# %%
chr(97)
# Out:
# 'a'

# %%
chr(67)
# Out:
# 'C'

# %%
ord('z')
# Out:
# 122

# %%
chr(128522)
# Out:
# '😊'

# %%
text = "Python"
result = ""
for i in range(len(text)):
  if text[i] in "aeiouAEIOU":
    result += text[i]

print(result)
# Out:
# o

# %%
word = "level"
same  = 0
for i in range(len(word)):
  if word[i] == word[-(i+1)]:
    same += 1

  print(same)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
word = "level"
same  = 0
for i in range(len(word)):
  if word[i] == word[-(i+1)]:
    same += 1

print(same)
# Out:
# 5

# %%
word = "level"
same  = 0
for i in range(len(word)):
  if word[i] == word[-(i+1)]:
    print(i, -(i+1), "-->" , word[i] , word[-(i+1)])
    same += 1

print(same)
# Out:
# 0 -1 --> l l
# 1 -2 --> e e
# 2 -3 --> v v
# 3 -4 --> e e
# 4 -5 --> l l
# 5

# %%
text = "Python"
result = ""
for i in range(len(text)):
    if i < len(text) // 2:
      result += text[i]
print(result)
# Out:
# Pyt

# %%
9//3
# Out:
# 3

# %%
24//5
# Out:
# 4

# %% [markdown]
# # FUNCTION the concept is used for code reuseablity

# %%
print("anurag singh")
# Out:
# anurag singh

# %%
len("vidhi singh")
# Out:
# 11

# %% [markdown]
# # How to create Function

# %%
# def function_name():
# defination

# %% [markdown]
# # def function_name():

# %%
def greet():
  print("Hello")

# %% [markdown]
# # function call

# %%
greet()
# Out:
# Hello

# %%
# Write a function that prints "Hello name" for whatever name you want

# %%
def name():
  print(input(),"hello name")

# %%
name()
# Out:
# Anurag singh
# Anurag singh hello name

# %%
greet()
# Out:
# Hello

# %%
# code reusability
# function definition ---> parameter
# function call --> argument

# %%
def greet(name):
  print("hello" , name)

# %%
greet("vidhi ")
# Out:
# hello vidhi

# %%
greet("Mrs singh")
# Out:
# hello Mrs singh

# %%
greet("vidhi")
# Out:
# hello vidhi

# %% [markdown]
# # Positional argument

# %%
def show(name , age):
  print("Name is", name)
  print("Age is", age)

# %%
show("anurag singh" , 20)
# Out:
# Name is anurag singh
# Age is 20

# %%
# code reusability
# function definition ---> parameter
# function call --> argument

# %%
show("vidhi  singh" , 24)
# Out:
# Name is vidhi  singh
# Age is 24

# %%
show(90 ,"vidhi  singh" )
# Out:
# Name is 90
# Age is vidhi  singh

# %% [markdown]
# # Keyworded arguments

# %%
def show(name, age):
  print("Name is", name)
  print("Age is", age)

# %%
show(name = "Raj" , age = 20)
# Out:
# Name is Raj
# Age is 20

# %%
show(age = 20, name = "Raj")
# Out:
# Name is Raj
# Age is 20

# %% [markdown]
# # Return keyword

# %%
def show(a,b):
  return a+b

# %%
s = show(2,3)
print(s)
# Out:
# 5

# %% [markdown]
# # Quiz

# %%
def greet():
  print("hello")

greet()
# Out:
# hello

# %%
def greet():
  print("welcome")

greet()
greet()
# Out:
# welcome
# welcome

# %%
def add(a,b):
  print(a+b)

add(10,20)
# Out:
# 30

# %%
def square(n):
  return n*n

square(9)
# Out:
# 81

# %%
def es():
  print("I love")

x = es()
print(x)
# Out:
# I love
# None

# %%
def multiply(a, b):
  return a * b

result = multiply(4, 5)
print(result)
# Out:
# 20

# %%
def message():
  print("Python")
x = message()
print(x)
# Out:
# Python
# None
