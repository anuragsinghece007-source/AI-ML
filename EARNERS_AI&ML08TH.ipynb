# %%
# wap to print odd numbers between 0 to 10
i = 0
while i<= 10:

  if i%2!=0:
    print(i)

  i+=1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# print the sum of all the numbers between 1 to 10 (both inclusive)
# 1. for loop
# 2. while
sum=0
for i in range(1,11):
  sum = sum+i
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
  sum = 0
  for i in range(1,11):
    sum += i
  print(sum)
# Out:
# 55

# %%
# n = 10 , 10*11/12 = 55

# %%
sum = 0
i = 1
while i<=10:
  sum += i
  i += 1
print(sum)
# Out:
# 55

# %%
# print the multiplication table of 5 till its first 10 multiple:
n = 5
i = 1

while i<=10:
  print(n, "*" , i , "=" , n*i)
  i += 1
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
# Quiz plus Practise
# What is the output?
count = 1
while count <= 3:
  print(count)
  count += 1
# A.
# 1
# 2
# 3
# B.
# 1
# 2
# 3
# 4
# C.
# 0
# Out:
# 1
# 2
# 3

# %%
# How many times will the following loop execute?
count = 5
while count <= 10:
  print(count)
  count += 1
# A. 5
# B. 6
# C. 10
# D. 12
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
# What is the output?
count = 10
while count >= 8:
   print(count)
   count -= 1
# Out:
# 10
# 9
# 8

# %%
count = 10
while count >= 8:
  print(count)
  count -= 2
# Out:
# 10
# 8

# %%
# Which statement is TRUE about a while loop?
# A. It always runs exactly 10 times.
# B. It runs as long as its condition is True.
# C. It can only print numbers.
# D. It always requires range().

# %%
# What is the output?
count = 1
while count < 1:
   print("Hello")

# nothing kuch nahi ayega condition phele hi false ho gayi hai

# %%
# What will this code print?
num = 2
while num <= 8:
  print(num)
  num += 2
# A.
# 2
# 4
# 6
# 8
# B.
# 2
# 4
# 6
# 8
# 10
# C.
# 1
# 3
# 5
# 7
# D. Infinite Loop
# Out:
# 2
# 4
# 6
# 8

# %%
# What is the output?
count = 5
while count > 0:
  print(count)
  count -= 2
# Out:
# 5
# 3
# 1

# %%
# What is the output?
count = 1
while count <= 5:
  count += 1
  print(count)
# A. 5
# B. 6
# C. 7
# D. ErrorA
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
# Which situation is best suited for a while loop?
# A. Print numbers from 1 to 10.
# B. Print multiplication table of 5.
# C. Keep asking for a password until the correct one is entered.
# D. Print the first 20 even numbers

# %%
# What is the output?
x = 0
while x < 3:
  print(x)
  x += 1
  print("Done")
# Out:
# 0
# Done
# 1
# Done
# 2
# Done

# %%
count = 1
while count <= 5:
  count += 1
print(count)
# Out:
# 6

# %%
p = " "
password = "Password@321"

while p!=password:
  p = input()
print("password is correct ")
# Out:
# password is correct
# password is correct
# password is correct
# password is correct
# password is correct

# %%
 p = " "
 password = "Password@321"

 while p!=password:
  p = input()

print("password is correct ")
