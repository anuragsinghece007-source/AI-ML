# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/EARNERS_AI%26ML1_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Earners AI and ML by Aditya Jain sir - Lecture 12

# %% [markdown]
# # Recap - String

# %%
s = "vidhi singh"
type(s)
# Out:
# str

# %%
n = len(s)
print(n)
# Out:
# 11

# %%
s[2]
# Out:
# 'd'

# %%
s[-1]
# Out:
# 'h'

# %%
print(s)
# Out:
# vidhi singh

# %%
a = s[2:7]
a
# Out:
# 'dhi s'

# %%
print(s[:6])
# Out:
# vidhi

# %%
for i in s:
  print(i, end = "")
# Out:
# vidhi singh

# %%
n = len(s)
for i in range(n):
  print(s[i], end ="")
# Out:
# vidhi singh

# %%
print(s)
# Out:
# vidhi singh

# %%
a = s.split(" ")
print(a)
# Out:
# ['vidhi', 'singh']

# %%
s = "anurag singh really love you vidhi singh"
a = s.split("  ")
print(a)
# Out:
# ['anurag singh really love you vidhi singh']

# %%
s = "Aditya Jain likes to do programming"
a = s.split(" ")
print(a)
# Out:
# ['Aditya', 'Jain', 'likes', 'to', 'do', 'programming']

# %%
s = "anurag singh really love you vidhi singh"
a = s.split(" ")
print(a)
# Out:
# ['anurag', 'singh', 'really', 'love', 'you', 'vidhi', 'singh']

# %%
s = "vidhi singh"
a = s.split(" ")
print(a)
# Out:
# ['vidhi', 'singh']

# %%
for ele in a :
  print(ele)
# Out:
# anurag singh really love you vidhi singh

# %%
s = "Aditya Jain likes to do programming"
a = s.split(" ")
print(a)
# Out:
# ['Aditya', 'Jain', 'likes', 'to', 'do', 'programming']

# %%
for elem in a:
  print(elem)
# Out:
# Aditya
# Jain
# likes
# to
# do
# programming

# %% [markdown]
# # HW - DPP- Tricky Advanced Questions

# %%
text = "Programming"
count = 0
for i in range(len(text)):
  if text[i] == text[-1]:
    count += 1
print(count)
# Out:
# 2

# %%
text = "Programming"
len(text)
# Out:
# 11

# %%
word = "PYTHON"
result = ""
for i in range(len(word)):
  if i % 2 == 1:
    result += word[i]

print(result)
# Out:
# YHN

# %%
text = "Data"
result = ""
for ch in text:
  result = ch + result
print(result)
# Out:
# ataD

# %%
text = "Data"
result = ""
for ch in text:
  result = result + ch
print(result)
# Out:
# Data

# %%
word = "Machine"
count = 0
for ch in word:
  if ch not in "aeiAEouIOU":
    count += 1
print(count)
# Out:
# 4

# %%
word = "Machine"
count = 0
for ch in word:
  if ch not in "aeiouAEIOU":
    count += 1
print(count)
# Out:
# 4

# %%
word = "python"

i = len(word)-1
while i >= 0:
  print(word[i], end="")
  i -= 2
# Out:
# nhy
