# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/Earners_Restart_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AI & ML by Aditya Jain - Lecture 1.1**
# Tentative Course Plan:
# # 1. Python Essentials --> 12
# # 2. Python for ML & AI --> 12
# # 3. SQL for ML & AI --> Structured Query Language --> 18
# # 4. Numpy --> Python Library for Numerical Python --> 6
# # 5. EDA using Pandas --> Efficiently deal with Tabular data using Python --> 12
# # 6. Data Visulization using Python --> Matplotlib, Seaborn --> 6
# # 7. Probability & Statistics --> 12
# # 8. Classical ML --> Classification, Regression --> 12
# # 9. Deep Learning --> Neural Networks. --> 12
# # 10. GenAI & Prompt Engineering --> LLM, Frameworks for Prompt Engineering. --> 16
# # 11. RAG, Agents , MCP --> 16
# # 12. Project & Deployment -->

# %% [markdown]
# # **Important Terminologies**

# %% [markdown]
# ## Algorithm--> step by step instructions to solve any problem.
#
#
#
# # Programming --> is a way of writing these insctrcutions in a language that the computer understands.
#
#
# ----------
# # Programming Languages --> C, C++, Python, Java, JavaScript...
#
# ----------
#
# # Why Python? -->
#
# # 1. Easy to understand --> programmer friendly
# # 2. Rich set of Libraries--> AI, ML, Web Dev, Automation...
#
#
# ----------
# # Python:
# # print("Hello World!")
#
#
#
# # Hello world program --> c++ and Python
# ----------
#
#
# # C++:
# # #include<iostream>
# # using namespace std;
# # int main()
# # {
# #
# # }
# cout << "Hello World!";
#
# ----------
# # What is Syntax?
# # Grammatical rules for that particular programming language
#
# # "Apple is Aditya Jain an eating"
# # ----------
# # "Aditya Jain is eating an Apple"
#
#
# ----------
#
# # Why Google Colab Notebook?
# # 1. No installation
# # 2. Free
# # 3. Runs in Browser ---> resources provided by google
# # 4. Used across industry

# %% [markdown]
# # Basics of Python Programming

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
print(Welcome to Python)
# Out:
#   File "/tmp/ipykernel_2565/1871024563.py", line 1
#     print(Welcome to Python)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("A") # multiple syntax on a screen
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A" , "B" , "C") # comma separted will give you automatically space seperated
# Out:
# A B C

# %%
print(100) # mathematically
# Out:
# 100

# %%
print(3+5)
# Out:
# 8

# %%
print(5-3)
# Out:
# 2

# %%
print(4*2)
# Out:
# 8

# %%
print("3+2")
# Out:
# 3+2

# %%
print(3+2)
# Out:
# 5

# %% [markdown]
# # Quizes

# %%
# 1. Which of the following is a common use of Python?
# A. AI & Machine Learning
# B. Data Science
# C. Automation
# D. All of the Above


#  answer D

# %%
# 2. What is Google Colab?
# A. A social media platform
# B. An online Python coding environment
# C. A gaming application
# D. A database

# Answer B.

# %%
# What will be the output?

# print("Hello World")

# A.
# Hello World

# B.
# "Hello World"

# C.
# print("Hello World")

# D. Error
# Answer A.

# %% [markdown]
# # Home work

# %%
# 1. What will be printed?

print(10)

# A. Ten
# B. "10"
# C. 10
# D. Error
# Out:
# 10

# %%
# 2. Guess the output:
print(5 + 3)

# Output?
# A. 53
# B. 8
# C. 5+3
# D. Error
# Out:
# 8

# %%
print("Thanks! Hope it was useful : )")
# Out:
# Thanks! Hope it was useful : )
