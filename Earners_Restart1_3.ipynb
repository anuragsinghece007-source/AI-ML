# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/Earners_Restart1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI & ML by Aditya Jain sir --> Lecture 3

# %% [markdown]
# # Recap

# %%
#variables
age = 20
print(age)
# Out:
# 20

# %%
print(Age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_528/2955847039.py in <cell line: 0>()
# ----> 1 print(Age)
#
# NameError: name 'Age' is not defined

# %%
type(10)
# Out:
# int

# %%
type(5.4)
# Out:
# float

# %%
type("anurag singh")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
a=input()
# Out:
# Anurag singh

# %%
type(a)
# Out:
# str

# %%
len = float(input())
# Out:
# 234.432

# %%
type(len)
# Out:
# float

# %% [markdown]
# # HW

# %%
# What does the following code do?
# name = input("Enter your name:")
# A. Prints the name
# B. Takes input from the user
# C. Deletes the name
# D. Creates an error

# %%
# What data type is returned by input()?
# A. int
# B. float
# C. bool
# D. str

# %%
# Which function converts a string to an integer?
# A.
# str()
# B.
# float()
# C.
# int()
# D.
# bool()

# %%
num = int("50")
print(type(num))

# A.
# <class 'str'>
# B.
# <class 'int'>
# C.
# <class 'float'>
# D. Error
# Out:
# <class 'int'>

# %%
type(num)
# Out:
# int

# %%
# age = 25
# age = 30
# print(age)
# A.
# 25
# B.
# 30
# C.
# 25 30
# D. Error

# %%
# What will be the output?
name = "Rahul"
print("Hello")
print(name)
# Out:
# Hello
# Rahul

# %% [markdown]
# # Arithmatic Operators

# %%
#Arithmatic Operators
print(5+4)
# Out:
# 9

# %%
print(4-8)
# Out:
# -4

# %%
print(10*3)
# Out:
# 30

# %%
print(20/4) # yha decimal m isliye ayya hai kyuki  integer ko add karne se float nahi ata hai
#  but python m do integer ka division python m float ho sakta hai kyuki pythin consistency maintain karta hai
# Out:
# 5.0

# %%
print(20/6)
# Out:
# 3.3333333333333335

# %%
#floored division operator positive value nearest lower whole number pure integer
print(20//6)
# Out:
# 3

# %%
print(10//5) # pure integer
# Out:
# 2

# %%
print(10/5)
# Out:
# 2.0

# %%
# Modulus --> gives remainder --> %
print(10%3)
# Out:
# 1

# %%
print(10%6)
# Out:
# 4

# %%
print(10%2)
# Out:
# 0

# %%
# power --> **
print(2**3)
# Out:
# 8

# %%
print(3**2)
# Out:
# 9

# %%
#Calculator -->
# take two int as input from the user, and print +,-,*,/,//,**,%

# %%
a = int(input())
b = int(input())
print( a+b , a-b , a*b , a/b , a//b , a**b , a%b )
# Out:
# 4
# 2
# 6 2 8 2.0 2 16 0

# %%
a = int(input())
b = int(input())
print("Addition: ", a+b)
print("Subtraction: ", a-b)
print("Multiplication: ", a*b)
print("Division: ", a/b)
print("Floored Division: ", a//b)
print("Modulus: ", a%b)
print("Power: ", a**b)
# Out:
# 4
# 2
# Addition:  6
# Subtraction:  2
# Multiplication:  8
# Division:  2.0
# Floored Division:  2
# Modulus:  0
# Power:  16

# %% [markdown]
# # Assignment Operators

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 10
x += 2
print(x)
# Out:
# 12

# %%
x = 10
x -= 4
print(x)
# Out:
# 6

# %%
x = 10
x *= 2
print(x)
# Out:
# 20

# %%
x = 10
x /= 2
print(x)
# Out:
# 5.0

# %%
x = 10
x **= 2
print(x)
# Out:
# 100

# %% [markdown]
# # Comparison Operators

# %%
10>5
# Out:
# True

# %%
4<3
# Out:
# False

# %%
10>=7
# Out:
# True

# %%
5<=5
# Out:
# True

# %%
5<5
# Out:
# False

# %%
5==5
# Out:
# True

# %%
a=5

# %%
a
# Out:
# 5

# %%
6 == 5
# Out:
# False

# %%
6!=6
# Out:
# False

# %%
7!=9
# Out:
# True

# %% [markdown]
# # Logical Operators

# %%
# and , or , not

# %%
4>3
# Out:
# True

# %%
5>2
# Out:
# True

# %%
(4>2) and (3>2) # in and both condition should true  it will gave true
# Out:
# True

# %%
(9>1) and (1>4)
# Out:
# False

# %%
(4 > 3) and (5 < 2)
# Out:
# False

# %%
(4<3)or(5>2) # in or atleast one condition should be true
# Out:
# True

# %%
# not --> toggle
# True --> False
# False --> True
(4 > 7)
# Out:
# False

# %%
not(2>4)
# Out:
# True

# %%
not(4==2)
# Out:
# True

# %%
not(4!=7)
# Out:
# False

# %%
not(3>3) and (6<3)
# Out:
# False

# %%
not((3>=3) and (6<3))
# Out:
# True

# %%
not((3>3) and(6<3 ))
# Out:
# True

# %% [markdown]
# # Membership Operator

# %%
"a" in "anuragsingh"
# Out:
# True

# %%
"b " in "Anurag"
# Out:
# False

# %% [markdown]
# # Quizes

# %%
print(10+5)
# Out:
# 15

# %%
print(20-8)
# Out:
# 12

# %%
print(6*4)
# Out:
# 24

# %%
print(15/3)
# Out:
# 5.0

# %%
print(17%5)
# Out:
# 2

# %%
print(4**2)
# Out:
# 16

# %%
print(20//3)
# Out:
# 6

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %%
salary = 50000
salary -= 10000
salary
# Out:
# 40000

# %%
marks = 40
print(marks>=40)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
x=5
x+=3
x*=2
print(x)
# Out:
# 16

# %%
age = 20
print(age >= 18 and age <=60)
# Out:
# True
