# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/Earners_AI_%26ML_Restrart_1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EARNERS AI&ML - LECTURE 1.4

# %% [markdown]
# # RECAP

# %%
type(10)
# Out:
# int

# %%
type(4.6)
# Out:
# float

# %%
type("a")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(false) # here this is a keyword  so ye kabhi bhi small letter m nahi ho sakta hai
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1288/2940563432.py in <cell line: 0>()
# ----> 1 type(false) # here this is a keyword  so ye kabhi bhi small letter m nahi ho sakta hai
#
# NameError: name 'false' is not defined

# %%
4!=6
# Out:
# True

# %%
5==5
# Out:
# True

# %%
(4!=6) or (5==5)
# Out:
# True

# %%
(4!=6) or (5!=5) # ek condition bhi true overall condition will be true
# Out:
# True

# %%
(4 != 6 ) and (5 == 5)
# Out:
# True

# %%
(4 != 6 ) and (5 == 5)
# Out:
# True

# %%
(4==6) and (5==5)
# Out:
# False

# %%
not(4!=6)
# Out:
# False

# %%
"v" in "vidhi"
# Out:
# True

# %% [markdown]
# # Decision making

# %%
# syntax: \
# if condition # other pl m hm log curly bracket
# ka use karte hai but here ither m space ka use karte hai jisse ye pta chata hai ki ye if ander fall karti hai statement

# %%
#Given the age of the person, check if they are eligibile to vote.
#if age is atleast 20, then they are eligible, else n
age = int(input("enter your age "))
if age > 18:
  print(" you are eligible to vote")
# Out:
# enter your age 90
#  you are eligible to vote

# %%
age = int(input("enter your age "))
if age>18:
  print("you are eligible to vote")
# Out:
# enter your age 25
# you are eligible to vote

# %%
age = 22 # here the concept come of indentation
if age >= 20:
print("right to vote")
# Out:
#   File "/tmp/ipykernel_1288/1367416096.py", line 3
#     print("right to vote")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
age = 22 # here the concept come of indentation
if age >= 20:
    print("e to vote")
# Out:
# e to vote

# %%
#Q2. Take the password from the user. If it matches "hello@123" then print "Welcome"

# %%
password = input("enter your password")
if password == "hello@123":
  print("welcome")
# Out:
# enter your passworda

# %%
password = input("enter your password")
if password == "hello@123":
  print("welcome")
# Out:
# enter your passwordhello@123
# welcome

# %%
# if-else
age = 19

if age >= 20:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# not eligible to vote

# %%
age = 22
if age >= 20:
  print("eligible to vote")
else:
  print("not eligible to vote")
# Out:
# eligible to vote

# %%
# Q2. Take the password from the user.
# If it matches "hello@123" then print "Welcome".
# Else, print "Invalid Password
password = input()
if password == "hello@123":
  print("welcome")
else:
  print("invalid password")
# Out:
# hello@123
# welcome

# %%
if 2 > 3:
 print("A")
else:
 print("B")
print("C")
# Out:
# B
# C

# %%
if 2 < 3:
 print("A")
else:
 print("B")
print("C")
# Out:
# A
# C

# %%
#elif
# marks =>
# marks < 30 --> "low"
# marks between 30 and 70 --> "Avg"
# marks > 70 --> "High"
# using if-else only

# %%
marks = 20
if marks < 30:
  print("low")
else:
  if marks >= 30 and marks <= 70:
    print("Avg")
  else:
    print("high")
# Out:
# low

# %%
marks = 12
if marks < 30:
  print("marks are low")
else:
  if marks > 30 and marks <= 70:
    print("theek thak")
  else:
    print("high")
# Out:
# marks are low

# %%
# else if ==> elif
if 2 > 3:
 print("A")
else:
 print("B")
# Out:
# B

# %%
# else if ==> elif
if 2 < 3:
 print("A")
else:
  print("B")
# Out:
# A

# %%
if 2 > 3:
 print("A")
elif 5 > 4:
 print("B")
else:
 print("C")
# Out:
# B

# %%
if 2 > 3:
 print("A")
elif 5 < 4:
 print("B")
else:
 print("C")
# Out:
# C

# %%
marks = 12
if marks < 30:
  print("marks are low")
elif marks > 30 and marks <= 70:
    print("theek thak")
else:
    print("high")
# Out:
# marks are low

# %%
# else if ==> elif
if 2>3:
  print("A")
else:
  print("B")
# Out:
# B

# %%
# else if ==> elif
if 2>3:
  print("A")
elif 5>4:
  print("B")
else:
 print("c")
# Out:
# B

# %%
# else if ==> elif
if 2<3:
  print("A")
elif 5>4:
  print("B")
else:
 print("c")
# Out:
# A

# %%
# else if ==> elif
if 2>3:
  print("A")
elif 5<4:
  print("B")
else:
 print("c")
# Out:
# c

# %%
# coolest CODE

marks = 30
if marks < 30:
  print("low")
elif (marks >= 30) and (marks <= 70):
  print("Avg")
else:
  print("High")
# Out:
# Avg

# %% [markdown]
# # QUIZ

# %%
age = 25
if age >= 18:
  print("vote")
# Out:
# vote

# %%
city = "pune"
if city == "pune"
    print("w t")
# Out:
#   File "/tmp/ipykernel_1288/76578844.py", line 2
#     if city == "pune"
#                      ^
# SyntaxError: expected ':'
