# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/2_2_EARNRES_(TUPLE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WHY WE NEED TUPLE

# %% [markdown]
# # TUPLE ==> UNALTERED LIST

# %%
# TUPLE IS IMMUTABLE LIST
# WE NEED TUPLE BECAUSE SOMETHING ARE FIXED LIKE WEEK NAMES MONDAY,......, SUNDAY

# %%
days = ["monday" , "tuesday" , "wednesday" , "thrusday" , "friday" , "saturday", "sunday"]

# %%
days
# Out:
# ['monday', 'tuesday', 'wednesday', 'thrusday', 'friday', 'saturday', 'sunday']

# %%
days[0] = "anuragsingh"

# %%
days
# Out:
# ['anuragsingh',
#  'tuesday',
#  'wednesday',
#  'thrusday',
#  'friday',
#  'saturday',
#  'sunday']

# %%
days = ("monday" , "tuesday" , "wednesday" , "thrusday" , "friday" , "saturday", "sunday")

# %%
days
# Out:
# ('monday', 'tuesday', 'wednesday', 'thrusday', 'friday', 'saturday', 'sunday')

# %%
days[0] = "aj"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_741/3466479348.py in <cell line: 0>()
# ----> 1 days[0] = "aj"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = ("aj" , "singh" ,34 , True)

# %%
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 34

# %%
b = ()
len(b)
# Out:
# 0

# %%
type(b)
# Out:
# tuple

# %%
a = (9) # how to crete one elememt tuple

# %% [markdown]
# # a = (9) # how to crete one elememt tuple

# %%
type(a)
# Out:
# int

# %% [markdown]
# # when we write a single integer in a bracket it will create int so we have to put,

# %%
d = ("vidhi singh",)

# %%
print(a)
# Out:
# 9

# %%
a = ("aj" , "singh" ,34 , True)

# %%
print(a)
# Out:
# ('aj', 'singh', 34, True)

# %% [markdown]
# # traverse a tuples

# %%
for i in a:
  print(i)
# Out:
# aj
# singh
# 34
# True

# %%
n = len(a)

for i in range(n):
  print(i, a[i])
# Out:
# 0 aj
# 1 singh
# 2 34
# 3 True

# %% [markdown]
# # tuple slicing

# %%
print(a[1:3])
# Out:
# ('singh', 34)

# %%
n = len(a)

for i in range(n):
  print(i, a[i])
# Out:
# 0 aj
# 1 singh
# 2 34
# 3 True

# %%
b = ("p" , "q" , "r")
print("p" in b)
# Out:
# True

# %%
b = ("p" , "q" , "r")
print("p" not in b)
# Out:
# False

# %%
num = (2,4,5)
print(sum(num))
# Out:
# 11

# %% [markdown]
# # HERE THE YOU CAN COUNT THE OCCURNECE

# %%
num = (2,3,4,5)
print(num.count(4))
# Out:
# 1

# %%
num = (2,3,4,4,44,45)
print(num.count(4))
# Out:
# 2

# %% [markdown]
# # HERE THE INDEX OF FIRST OCCURENCE

# %%
num.index(4)
# Out:
# 2

# %% [markdown]
# # packing and unpacking

# %%
student = ("raj", 9.9 , 24)

# %%
type(student)
# Out:
# tuple

# %%
# unpacking ----> opening a box

# %% [markdown]
# # # unpacking ----> opening a box

# %%
name , cgpa , age = student

# %%
print(name)
# Out:
# raj

# %%
print(cgpa)
# Out:
# 9.9

# %%
name , cgpa , age = ("raj" , 9.9 , 24)
print(name , age , cgpa)
# Out:
# raj 24 9.9

# %%
def show():
  return 2,3

# %%
show()
# Out:
# (2, 3)

# %%
a = show()

# %%
a
# Out:
# (2, 3)

# %%
def show(a,b):
  print(a+b)

c = show(2,4)
print(c)
# Out:
# 6
# None

# %%
def show(a,b,c=9):
  return(a+b+c)

show(2,3)
# Out:
# 14

# %%
def show():
  return 2,2

# %%
a = show()
print(a)
# Out:
# (2, 2)

# %% [markdown]
# # QUIZ

# %%
t = 5

# %%
type(t)
# Out:
# int

# %%
t = (5,)
type(t)
# Out:
# tuple

# %% [markdown]
# # aggregation function

# %%
numbers = (11 , 20 , 30)
print(len(numbers))
# Out:
# 3

# %%
numbers = (11 , 20 , 30)
print(min(numbers))
# Out:
# 11

# %%
numbers = (11 , 20 , 30)
print(max(numbers))
# Out:
# 30

# %%
numbers = (11 , 20 , 30)
print(sum(numbers))
# Out:
# 61

# %%
numbers = (11 , 20 , 30)
print(numbers.count(20))
# Out:
# 1

# %%
numbers = (11 , 20 , 30)
print(numbers.index(20))
# Out:
# 1

# %%
numbers = (11 , 20 , 30)

for color in numbers:
  print(color)
# Out:
# 11
# 20
# 30

# %% [markdown]
# # INPORTANT INDUSTRY SKILLS

# %%
c = ("r" , "g" , "b")

for ele in c:
  print(ele)
# Out:
# r
# g
# b

# %%
c = ("r" , "g" , "b")
print("r" in c)
# Out:
# True

# %%
c = ("r" , "g" , "b")
print("R" in c)
# Out:
# False

# %% [markdown]
# # concept of immutable we learn

# %%
numbers = (11 , 20 , 30)
numbers[1] = 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_741/1779244776.py in <cell line: 0>()
#       1 numbers = (11 , 20 , 30)
# ----> 2 numbers[1] = 50
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # strings are immutable

# %%
name = "anr"
name[2] = "u"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_741/582248539.py in <cell line: 0>()
#       1 name = "anr"
# ----> 2 name[2] = "u"
#
# TypeError: 'str' object does not support item assignment
