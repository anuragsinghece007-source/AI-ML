# %% [markdown]
# **EARNERS AI&ML BY ADITYA JAIN SIR - LECTURE-1.10**

# %% [markdown]
# **Recap**

# %%
for i in range(5):
  for j in range(6,10):
    print(i,j)
# Out:
# 0 6
# 0 7
# 0 8
# 0 9
# 1 6
# 1 7
# 1 8
# 1 9
# 2 6
# 2 7
# 2 8
# 2 9
# 3 6
# 3 7
# 3 8
# 3 9
# 4 6
# 4 7
# 4 8
# 4 9

# %%
for i in range(2):
  for j in range(2):
    print(j , end = "  ")
  print()
# Out:
# 0  1
# 0  1

# %%
for row in range(4):
  for col in range(4):
    print("*" , end = " ")
  print()
# Out:
# * * * *
# * * * *
# * * * *
# * * * *

# %%
for i in range(1,3):
  for j in range(1,3):
    print(i,j , i+j , end = " ")
  print()
# Out:
# 1 1 2 1 2 3
# 2 1 3 2 2 4

# %% [markdown]
# List in python

# %% [markdown]
# *whenever we want to store a collection be create a list
#
#
#
# list can store any data type but here array store only similar data type

# %%
m1 = 90
m2 = 87
m3 = 95
m4 = 83
m5 = 70

# %%
marks = [1,2,3,4,5,6]

# %%
marks
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(marks)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [45 , "AS" , 6.8 ,True]

# %%
a
# Out:
# [45, 'AS', 6.8, True]

# %%
type(a)
# Out:
# list

# %%
print(a)
# Out:
# [45, 'AS', 6.8, True]

# %%
type(marks)
# Out:
# list

# %%
# how to create empty list
students = []
print(students)
# Out:
# []

# %% [markdown]
# *Indexing text*

# %%
print(marks)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
marks[0]
# Out:
# 1

# %%
marks[4]
# Out:
# 5

# %%
# how to access the last element
n = len(marks)

# %%
n
# Out:
# 6

# %%
marks[n-1]
# Out:
# 6

# %%
marks[n-2]
# Out:
# 5

# %%
marks[-1]
# Out:
# 6

# %%
marks[-6]
# Out:
# 1

# %%
# in list if you have n element then it start from 0 to n-1 if it start from last then it goes from last  to -1 to -n

# %%
marks
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
marks[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1690/1891664175.py in <cell line: 0>()
# ----> 1 marks[6]
#
# IndexError: list index out of range

# %%
marks[2] = 100

# %%
marks
# Out:
# [1, 2, 100, 4, 5, 6]

# %% [markdown]
# **Iterative over a list**

# %%
n = len(marks)
print(n)
# Out:
# 6

# %%
marks[2]
# Out:
# 100

# %%
for i in range(n):
  print(marks[i])
# Out:
# 1
# 2
# 100
# 4
# 5
# 6

# %%
marks[0] = 89

# %%
marks
# Out:
# [89, 2, 100, 4, 5, 6]

# %%
for element in marks: # this is a another way to access all the element in the list
  print(element)
# Out:
# 89
# 2
# 100
# 4
# 5
# 6

# %%
# for element in marks: # this is a another way to access all the element in the list
#   print(element)




# when we have a restriction like we have to print only the even indexing no then we use such method

# %% [markdown]
# ** for element in marks: # this is a another way to access all the element in the list
# ** for element in marks: # this is a another way to access all the element in the list **
#  print(element)
#
#
#
#
# # when we have a restriction like we have to print only the even indexing no then we use such method**

# %% [markdown]
# ** **for** element in marks: # this is a another way to access all the element in the list
#   print(element)
#
#
#
#
# # when we have a restriction like we have to print only the even indexing no then we use such method**

# %%
# write a code to print the elements present at the even indexes
for i in range(n):
  if i%2 == 0:
    print(marks[i])
# Out:
# 89
# 100
# 5

# %%
# write a code to print all the even elements.
for i  in range(n):
  if marks[i]%2 == 0:
    print(marks[i])
# Out:
# 2
# 100
# 4
# 6

# %%
for ele in marks:
  if ele%2 == 0:
    print(ele)
# Out:
# 2
# 100
# 4
# 6

# %% [markdown]
# **QUIZ**

# %%
# WHAT IS THE OUTPUT
numbers = [10 , 20, 30]
print(numbers[0])
# Out:
# 10

# %%
# What is the output?
fruits = ["Apple", "Banana", "Mango"]
print(fruits[-1])
# Out:
# Mango

# %%
# What is the output?
numbers = [10,20]
print(numbers[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1690/3400737244.py in <cell line: 0>()
#       1 # What is the output?
#       2 numbers = [10,20]
# ----> 3 print(numbers[2])
#
# IndexError: list index out of range

# %%
# What is the output?
numbers = [1,2,3]
for num in numbers:
  print(num)
# Out:
# 1
# 2
# 3

# %%
 # What is printed?
numbers = [5,10,15]
for i in range(len(numbers)):
  print(numbers[i])
# Out:
# 5
# 10
# 15

# %%
# What is the output?
fruits = ["Apple","Banana","Mango"]
fruits[1] = "Orange"
print(fruits)
# Out:
# ['Apple', 'Orange', 'Mango']

# %%
# What is the output?
numbers = [10,20]
print(numbers[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1690/3400737244.py in <cell line: 0>()
#       1 # What is the output?
#       2 numbers = [10,20]
# ----> 3 print(numbers[2])
#
# IndexError: list index out of range

# %%
# What is the output?
numbers = [1,2,3]
for num in numbers:
  print(num)
# Out:
# 1
# 2
# 3

# %%
# What is printed?
numbers = [5,10,15]
for i in range(len(numbers)):
  print(numbers[i])
# Out:
# 5
# 10
# 15

# %%
# What is the output?
marks = [60,70,80,90]
print(max(marks))
# Out:
# 90

# %%
# What is the output?
marks = [60,70,80,90]
print(min(marks))
# Out:
# 60

# %%
#Write a code to find the sum of all the elements of the list.
marks = [60,70,80,90]
sm = 0
for elem in marks:
  sm = sm + elem
  print(sm)
# Out:
# 60
# 130
# 210
# 300

# %%
#Write a code to find the average of all the elements of the list.
#Write a code to find the sum of all the elements of the list.
marks = [60,70,80,90]
sm = 0
for elem in marks:
  sm = sm + elem
print(sm/len(marks))
# Out:
# 75.0

# %%
# What is printed?
numbers = [9,5,7,1]
print(sorted(numbers))
# Out:
# [1, 5, 7, 9]

# %%
numbers
# Out:
# [9, 5, 7, 1]

# %%
numbers.sort()

# %%
# What is the output?
names = ["A","B","C"]
print(names[len(names)-1])
# Out:
# C

# %%
numbers = [10, 20, 30]
print(numbers[-1])
numbers[-1] = 100
print(numbers)
# Out:
# 30
# [10, 20, 100]

# %%
number = [5 , 10 , 15]
number[1] = number[0]+number[2]
number[1]
# Out:
# 20

# %%
numbers = [5, 10, 15]
numbers[1] = numbers[0] + numbers[2]
#print(numbers)
print(sum(numbers))
# Out:
# 40

# %%
marks = [50, 60, 70, 80]
for i in range(len(marks)):
  marks[i] = marks[i] + 5
print(marks)
# Out:
# [55, 65, 75, 85]

# %%
data = [2, 4, 6]
for i in range(len(data)):
  print(i, data[i])
# Out:
# 0 2
# 1 4
# 2 6

# %%
numbers = [8, 2, 5, 1]
print(min(numbers))
print(max(numbers))
print(max(numbers) - min(numbers))
# Out:
# 1
# 8
# 7

# %%
items = [1, 2, 3]
for i in range(len(items)):
  items[i] = items[i] * 2
print(sum(items))
# Out:
# 12
