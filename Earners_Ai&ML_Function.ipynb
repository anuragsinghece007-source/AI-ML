# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsinghece007-source/AI-ML/blob/main/Earners_Ai%26ML_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# def function_name:
# defination

# %%
def greet(): # function define
  print("hello")

# %%
greet() # function call
# Out:
# hello

# %%
# write a function that print "hello name" for whatever aname you want
def name():
  return name
# my code

# %%
name("vidhi")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1587/2591787899.py in <cell line: 0>()
# ----> 1 name("vidhi")
#
# TypeError: name() takes 0 positional arguments but 1 was given

# %%
# code reusability

# %% [markdown]
# # parameter and argument

# %%
# code resuablity
# function defination --> parameter
# function call ---> argumnet

# %%
def greet(name):
  return name

# %%
greet("vidhi")
# Out:
# 'vidhi'

# %%
def greet(name):
  print("Hello" , name)

# %%
greet("anurag singh")
# Out:
# Hello anurag singh

# %%
greet("pushkar chauhan")
# Out:
# Hello pushkar chauhan

# %% [markdown]
# # Positional argument

# %%
def show(name , age):
  print("Name is", name)
  print("Age is", age)

# %%
show("anurag singh" , 20)
# Out:
# Name is anurag singh
# Age is 20

# %%
# code reusability
# function definition ---> parameter
# function call --> argument

# %%
show("vidhi  singh" , 24)
# Out:
# Name is vidhi  singh
# Age is 24

# %%
show(90 ,"vidhi  singh" )
# Out:
# Name is 90
# Age is vidhi  singh

# %%
# Keyworded arguments

# %%
def show(name, age):
  print("Name is", name)
  print("Age is", age)

# %%
show(90 ,"vidhi  singh" ) # problem
# Out:
# Name is 90
# Age is vidhi  singh

# %% [markdown]
# # Problem solution keyworded arguments

# %%
def show(name, age):
  print("Name is", name)
  print("Age is", age)

# %%
show(name = "Raj" , age = 20)
# Out:
# Name is Raj
# Age is 20

# %% [markdown]
# # Return keyword

# %%
def show(a,b):
  return a+b

# %%
show(9,8)
# Out:
# 17

# %%
s = show(2,3)
print(s)
# Out:
# 5

# %% [markdown]
# # QUIZ

# %%
def greet():
  print("hello")

greet()
# Out:
# hello

# %%
def greet():
  print("welcome")

greet()
greet()
# Out:
# welcome
# welcome

# %%
def add(a,b):
  print(a+b)

add(10,20)
# Out:
# 30

# %%
def square(n):
  return n*n

square(9)
# Out:
# 81

# %%
def square(n):
  return n*n

square(9)
# Out:
# 81

# %%
def es():
  print("I love")

x = es()
print(x)
# Out:
# I love
# None

# %%
def multiply(a, b):
  return a * b

result = multiply(4, 5)
print(result)
# Out:
# 20

# %%
def message():
  print("Python")
x = message()
print(x)
# Out:
# Python
# None

# %%
def show():
  print("Hello Friends!")

# %%
show()
# Out:
# Hello Friends!

# %%
show()
# Out:
# Hello Friends!

# %%
def show(name ,  age ):
  print("name is", name)
  print("age is", age)

# %%
show("vidhi", 24)
# Out:
# name is vidhi
# age is 24

# %%
show(24, "vidhi")
# Out:
# name is 24
# age is vidhi

# %%
show(name = "Raj", age = 20)
# Out:
# name is Raj
# age is 20

# %%
#default argument
def show(name = "Raj"):
  print(name)

# %%
show()
# Out:
# Raj

# %%
show("vidhi singh")
# Out:
# vidhi singh

# %%
show()
# Out:
# Raj
